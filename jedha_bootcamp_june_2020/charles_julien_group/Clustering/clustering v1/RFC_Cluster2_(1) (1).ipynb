# %%
import pandas as pd
import numpy as np

# %%
df_cluster = pd.read_csv("df_cluster2.csv")

# %%
df_cluster.head()
# Out:
#    Unnamed: 0  Patient  ...  ratio_sd2_sd1_std  crisis_frequency
# 0           0        2  ...           1.928270          0.231270
# 1           1       17  ...           2.481816          0.008065
# 2           9      175  ...           0.613767          0.000000
# 3          14      255  ...           0.627420          0.006993
# 4          15      258  ...           2.781973          0.445148
#
# [5 rows x 58 columns]

# %%
s = pd.Series(df_cluster['Patient'])

# %%
s
# Out:
# 0          2
# 1         17
# 2        175
# 3        255
# 4        258
#        ...
# 232    13085
# 233    13103
# 234    13145
# 235    13336
# 236    13400
# Name: Patient, Length: 237, dtype: int64

# %%
l_2 = s.values.tolist()

# %%
l_2
# Out:
# [2,
#  17,
#  175,
#  255,
#  258,
#  287,
#  289,
#  427,
#  458,
#  609,
#  629,
#  659,
#  675,
#  752,
#  762,
#  775,
#  795,
#  827,
#  900,
#  906,
#  908,
#  922,
#  1026,
#  1027,
#  1030,
#  1034,
#  1081,
#  1113,
#  1291,
#  1324,
#  1331,
#  1349,
#  1479,
#  1587,
#  1605,
#  1640,
#  1681,
#  1795,
#  1797,
#  1891,
#  1986,
#  2021,
#  2044,
#  2235,
#  2236,
#  2289,
#  2348,
#  2445,
#  2448,
#  2478,
#  2489,
#  2657,
#  2806,
#  2868,
#  2881,
#  2886,
#  3011,
#  3036,
#  3053,
#  3061,
#  3101,
#  3208,
#  3281,
#  3623,
#  3636,
#  3843,
#  3977,
#  4025,
#  4049,
#  4141,
#  4220,
#  4294,
#  4338,
#  4434,
#  4512,
#  4523,
#  4526,
#  4596,
#  4746,
#  4799,
#  4801,
#  4803,
#  4836,
#  4841,
#  4921,
#  5025,
#  5031,
#  5103,
#  5169,
#  5208,
#  5233,
#  5275,
#  5300,
#  5371,
#  5427,
#  5476,
#  5479,
#  5526,
#  5533,
#  5633,
#  5762,
#  5765,
#  6103,
#  6134,
#  6352,
#  6408,
#  6452,
#  6455,
#  6507,
#  6514,
#  6535,
#  6546,
#  6562,
#  6698,
#  6771,
#  6774,
#  6900,
#  6986,
#  7032,
#  7092,
#  7094,
#  7122,
#  7235,
#  7279,
#  7446,
#  7458,
#  7475,
#  7555,
#  7617,
#  7633,
#  7684,
#  7771,
#  7802,
#  7828,
#  7835,
#  7839,
#  7913,
#  7929,
#  7937,
#  7952,
#  8053,
#  8156,
#  8164,
#  8174,
#  8188,
#  8204,
#  8295,
#  8453,
#  8461,
#  8471,
#  8481,
#  8574,
#  8615,
#  8706,
#  8730,
#  8738,
#  8823,
#  8859,
#  8886,
#  8953,
#  8971,
#  8980,
#  9107,
#  9152,
#  9158,
#  9162,
#  9231,
#  9245,
#  9307,
#  9352,
#  9528,
#  9570,
#  9630,
#  9632,
#  9669,
#  9697,
#  9839,
#  9852,
#  9866,
#  9885,
#  9902,
#  9906,
#  9932,
#  10022,
#  10079,
#  10088,
#  10135,
#  10148,
#  10158,
#  10301,
#  10364,
#  10412,
#  10418,
#  10421,
#  10435,
#  10450,
#  10517,
#  10549,
#  10555,
#  10563,
#  10659,
#  10678,
#  10843,
#  11063,
#  11083,
#  11330,
#  11333,
#  11455,
#  11468,
#  11575,
#  11580,
#  11618,
#  11684,
#  11815,
#  11834,
#  11870,
#  11873,
#  11914,
#  11972,
#  12526,
#  12615,
#  12679,
#  12695,
#  12700,
#  12707,
#  12742,
#  12887,
#  12940,
#  12960,
#  12964,
#  12973,
#  13011,
#  13085,
#  13103,
#  13145,
#  13336,
#  13400]

# %%
df_label = pd.read_csv('xqrs_v2_cleaned.csv')

# %%
df_label.head()
# Out:
#    Unnamed: 0    Set Categorie Montage  ...  mean_nni%       csi%        hf%
# 0         193  train         01_tcp_ar  ...      100.0  76.666667  46.666667
# 1         194  train         01_tcp_ar  ...      100.0  76.666667  46.666667
# 2         195  train         01_tcp_ar  ...      100.0  76.666667  46.666667
# 3         196  train         01_tcp_ar  ...      100.0  76.666667  46.666667
# 4         197  train         01_tcp_ar  ...      100.0  76.666667  46.666667
#
# [5 rows x 45 columns]

# %%
df_label_work = df_label[df_label['Patient'].isin(l_2)]

# %%
df_label_work
# Out:
#        Unnamed: 0    Set Categorie Montage  ...  mean_nni%  csi%     hf%
# 30           1019  train         01_tcp_ar  ...    98.4000  90.4  76.000
# 31           1020  train         01_tcp_ar  ...    98.4000  90.4  76.000
# 32           1021  train         01_tcp_ar  ...    98.4000  90.4  76.000
# 33           1022  train         01_tcp_ar  ...    98.4000  90.4  76.000
# 34           1023  train         01_tcp_ar  ...    98.4000  90.4  76.000
# ...           ...    ...               ...  ...        ...   ...     ...
# 99901      143312  train         01_tcp_ar  ...    85.9375  75.0  65.625
# 99902      143313  train         01_tcp_ar  ...    85.9375  75.0  65.625
# 99903      143314  train         01_tcp_ar  ...    85.9375  75.0  65.625
# 99904      143315  train         01_tcp_ar  ...    85.9375  75.0  65.625
# 99905      143316  train         01_tcp_ar  ...    85.9375  75.0  65.625
#
# [43342 rows x 45 columns]

# %%
df_label_def = df_label_work.drop(['Unnamed: 0','Set','Categorie Montage','Dossier Patient','File N°','exam_duration','Pan_vs_XQRS','SWT_vs_XQRS','Session','max_duration','mean_nni%','csi%','hf%'],axis=1)

# %%
df_label_def
# Out:
#        Patient  ...                                   cle_exam
# 30        8615  ...  train_01_tcp_ar_8615_s001_2012_01_13_t000
# 31        8615  ...  train_01_tcp_ar_8615_s001_2012_01_13_t000
# 32        8615  ...  train_01_tcp_ar_8615_s001_2012_01_13_t000
# 33        8615  ...  train_01_tcp_ar_8615_s001_2012_01_13_t000
# 34        8615  ...  train_01_tcp_ar_8615_s001_2012_01_13_t000
# ...        ...  ...                                        ...
# 99901     7839  ...  train_01_tcp_ar_7839_s002_2014_10_11_t004
# 99902     7839  ...  train_01_tcp_ar_7839_s002_2014_10_11_t004
# 99903     7839  ...  train_01_tcp_ar_7839_s002_2014_10_11_t004
# 99904     7839  ...  train_01_tcp_ar_7839_s002_2014_10_11_t004
# 99905     7839  ...  train_01_tcp_ar_7839_s002_2014_10_11_t004
#
# [43342 rows x 32 columns]

# %%
df_RF = df_label_def.replace([np.inf, -np.inf], np.nan)

# %%
df_RF = df_RF.groupby(df_RF['cle_exam']).transform(lambda x: x.fillna(x.mean()))

# %%
df_RF
# Out:
#        Patient  interval_index  ...  ratio_sd2_sd1     label
# 30        8615             0.0  ...       3.966822  0.000000
# 31        8615             1.0  ...       3.966822  0.000000
# 32        8615             2.0  ...       3.966822  0.000000
# 33        8615             3.0  ...       3.966822  0.000000
# 34        8615             4.0  ...       3.966822  0.000000
# ...        ...             ...  ...            ...       ...
# 99901     7839            59.0  ...       4.279437  0.000000
# 99902     7839            60.0  ...       4.790177  0.000000
# 99903     7839            61.0  ...       3.535825  0.000000
# 99904     7839            62.0  ...       3.424155  0.000000
# 99905     7839            63.0  ...       3.266522  0.093335
#
# [43342 rows x 31 columns]

# %%
df_RF['label'] = df_RF['label'].apply(lambda x: "1" if (x!=0) else  "0" )

# %%
df_RF['label']
# Out:
# 30       0
# 31       0
# 32       0
# 33       0
# 34       0
#         ..
# 99901    0
# 99902    0
# 99903    0
# 99904    0
# 99905    1
# Name: label, Length: 43342, dtype: object

# %%
a = pd.Series(df_RF['label'])

# %%
a.value_counts()
# Out:
# 0    40845
# 1     2497
# Name: label, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X = df_RF.iloc[:, :-1]
y = df_RF.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,stratify=y)

# %%
from sklearn.preprocessing import StandardScaler

numeric_transformer = StandardScaler()

X_train = numeric_transformer.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-0.22384675, -0.928444  , -0.928444  , ...,  0.34241313,
#          0.67867631,  0.18236935],
#        [-0.42158417,  0.26478617,  0.26478617, ...,  1.52792571,
#          3.72324622,  1.09051804],
#        [-0.75717847, -0.45612373, -0.45612373, ...,  1.81116234,
#          3.10054386,  0.48117973],
#        ...,
#        [ 0.22756048, -0.85386712, -0.85386712, ...,  0.02720599,
#          0.07596058, -0.1512332 ],
#        [ 1.26428364,  0.86140125,  0.86140125, ...,  0.06068738,
#         -0.206952  , -0.5615776 ],
#        [-0.22384675,  0.26478617,  0.26478617, ...,  0.15699247,
#         -0.26409924, -0.72024489]])

# %%
from sklearn.ensemble import RandomForestClassifier
rf_classifier = RandomForestClassifier(n_estimators=50)
rf_classifier.fit(X_train, y_train)
rf_classifier.score(X_train, y_train)
# Out:
# 0.9998681564982366

# %%
from sklearn.model_selection import GridSearchCV
rf_classifier_grid = RandomForestClassifier()
params = {"n_estimators": range(20, 50)}

classifier = GridSearchCV(cv=10, estimator = rf_classifier_grid, param_grid = params).fit(X_train, y_train)

# %%
classifier.best_params_
# Out:
# {'n_estimators': 47}

# %%
X_test = numeric_transformer.fit_transform(X_test)

# %%
classifier.best_estimator_.score(X_test, y_test)
# Out:
# 0.9603168499577021

# %%
y_pred = classifier.predict(X_test)
print(y_pred)
# Out:
# ['0' '0' '0' ... '0' '0' '0']

# %%
print(y_test)
# Out:
# 40341    0
# 26030    0
# 8622     0
# 72414    0
# 34317    0
#         ..
# 88711    0
# 85189    0
# 96722    1
# 54057    0
# 35546    0
# Name: label, Length: 13003, dtype: object

# %%
from sklearn.metrics import f1_score
f1_score(y_test, y_pred,average='binary',pos_label='1')
# Out:
# 0.5009671179883946

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d")

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, labels=[0,1]))
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:565: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask &= (ar1 != a)
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98     12254
#            1       0.91      0.35      0.50       749
#
#    micro avg       0.96      0.96      0.96     13003
#    macro avg       0.94      0.67      0.74     13003
# weighted avg       0.96      0.96      0.95     13003

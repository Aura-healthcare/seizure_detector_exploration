# %%
import pandas as pd
import numpy as np

# %%
df_cluster = pd.read_csv("df_cluster0_v2.csv")

# %%
df_cluster.head()
# Out:
#    Unnamed: 0  Patient  ...  ratio_sd2_sd1_std  crisis_frequency
# 0           0        2  ...           1.928270          0.231270
# 1           1       17  ...           2.481816          0.008065
# 2           2       21  ...           1.084055          0.000000
# 3           3       32  ...           0.983092          0.008130
# 4           4       54  ...           1.318584          0.007692
#
# [5 rows x 22 columns]

# %%
s = pd.Series(df_cluster['Patient'])

# %%
s
# Out:
# 0          2
# 1         17
# 2         21
# 3         32
# 4         54
#        ...
# 297    13112
# 298    13145
# 299    13336
# 300    13400
# 301    13407
# Name: Patient, Length: 302, dtype: int64

# %%
l_1 = s.values.tolist()

# %%
l_1
# Out:
# [2,
#  17,
#  21,
#  32,
#  54,
#  107,
#  175,
#  184,
#  216,
#  254,
#  255,
#  258,
#  287,
#  289,
#  427,
#  458,
#  529,
#  569,
#  604,
#  609,
#  629,
#  659,
#  675,
#  762,
#  775,
#  795,
#  820,
#  900,
#  906,
#  908,
#  922,
#  924,
#  1006,
#  1027,
#  1030,
#  1050,
#  1113,
#  1116,
#  1188,
#  1291,
#  1331,
#  1349,
#  1402,
#  1413,
#  1479,
#  1503,
#  1545,
#  1587,
#  1605,
#  1640,
#  1681,
#  1795,
#  1797,
#  1891,
#  1981,
#  1986,
#  2000,
#  2021,
#  2044,
#  2051,
#  2225,
#  2232,
#  2235,
#  2236,
#  2289,
#  2348,
#  2384,
#  2394,
#  2448,
#  2478,
#  2484,
#  2489,
#  2543,
#  2568,
#  2657,
#  2707,
#  2806,
#  2847,
#  2868,
#  2881,
#  2886,
#  2921,
#  3036,
#  3053,
#  3061,
#  3101,
#  3208,
#  3281,
#  3284,
#  3306,
#  3437,
#  3623,
#  3674,
#  3843,
#  3849,
#  3960,
#  4025,
#  4030,
#  4049,
#  4126,
#  4141,
#  4220,
#  4294,
#  4338,
#  4374,
#  4512,
#  4523,
#  4526,
#  4594,
#  4596,
#  4657,
#  4671,
#  4719,
#  4746,
#  4801,
#  4803,
#  4836,
#  4841,
#  4921,
#  5025,
#  5103,
#  5169,
#  5208,
#  5213,
#  5233,
#  5275,
#  5300,
#  5301,
#  5427,
#  5476,
#  5479,
#  5526,
#  5575,
#  5649,
#  5672,
#  5762,
#  5765,
#  6059,
#  6103,
#  6134,
#  6352,
#  6408,
#  6452,
#  6455,
#  6514,
#  6535,
#  6546,
#  6562,
#  6648,
#  6698,
#  6771,
#  6774,
#  6900,
#  6986,
#  7067,
#  7094,
#  7122,
#  7128,
#  7130,
#  7235,
#  7255,
#  7279,
#  7431,
#  7446,
#  7458,
#  7475,
#  7584,
#  7633,
#  7665,
#  7684,
#  7802,
#  7828,
#  7835,
#  7839,
#  7913,
#  7929,
#  7936,
#  7937,
#  7952,
#  8053,
#  8143,
#  8156,
#  8164,
#  8174,
#  8188,
#  8204,
#  8295,
#  8303,
#  8345,
#  8444,
#  8453,
#  8461,
#  8471,
#  8481,
#  8606,
#  8615,
#  8660,
#  8706,
#  8730,
#  8738,
#  8823,
#  8859,
#  8886,
#  8889,
#  8941,
#  8953,
#  8971,
#  8980,
#  9044,
#  9104,
#  9152,
#  9162,
#  9231,
#  9245,
#  9307,
#  9352,
#  9370,
#  9528,
#  9570,
#  9623,
#  9630,
#  9632,
#  9669,
#  9762,
#  9852,
#  9866,
#  9881,
#  9885,
#  9902,
#  9906,
#  9932,
#  9934,
#  10022,
#  10035,
#  10079,
#  10088,
#  10135,
#  10148,
#  10158,
#  10164,
#  10268,
#  10275,
#  10291,
#  10301,
#  10364,
#  10418,
#  10421,
#  10427,
#  10435,
#  10461,
#  10489,
#  10517,
#  10547,
#  10549,
#  10555,
#  10563,
#  10587,
#  10591,
#  10659,
#  10678,
#  10798,
#  11063,
#  11083,
#  11330,
#  11333,
#  11468,
#  11562,
#  11575,
#  11618,
#  11684,
#  11815,
#  11834,
#  11870,
#  11873,
#  11914,
#  11915,
#  11972,
#  12070,
#  12229,
#  12484,
#  12615,
#  12679,
#  12695,
#  12700,
#  12707,
#  12759,
#  12887,
#  12940,
#  12957,
#  12960,
#  12964,
#  12966,
#  12973,
#  12978,
#  13011,
#  13095,
#  13103,
#  13112,
#  13145,
#  13336,
#  13400,
#  13407]

# %%
df_label = pd.read_csv('xqrs_v2_cleaned.csv')

# %%
df_label.head()
# Out:
#    Unnamed: 0    Set Categorie Montage  ...  mean_nni%       csi%        hf%
# 0         193  train         01_tcp_ar  ...      100.0  76.666667  46.666667
# 1         194  train         01_tcp_ar  ...      100.0  76.666667  46.666667
# 2         195  train         01_tcp_ar  ...      100.0  76.666667  46.666667
# 3         196  train         01_tcp_ar  ...      100.0  76.666667  46.666667
# 4         197  train         01_tcp_ar  ...      100.0  76.666667  46.666667
#
# [5 rows x 45 columns]

# %%
df_label_work = df_label[df_label['Patient'].isin(l_1)]

# %%
df_label_work
# Out:
#        Unnamed: 0    Set Categorie Montage  ...  mean_nni%       csi%        hf%
# 30           1019  train         01_tcp_ar  ...  98.400000  90.400000  76.000000
# 31           1020  train         01_tcp_ar  ...  98.400000  90.400000  76.000000
# 32           1021  train         01_tcp_ar  ...  98.400000  90.400000  76.000000
# 33           1022  train         01_tcp_ar  ...  98.400000  90.400000  76.000000
# 34           1023  train         01_tcp_ar  ...  98.400000  90.400000  76.000000
# ...           ...    ...               ...  ...        ...        ...        ...
# 64594       91233  train         01_tcp_ar  ...  96.774194  77.419355  48.387097
# 64595       91234  train         01_tcp_ar  ...  96.774194  77.419355  48.387097
# 64596       91235  train         01_tcp_ar  ...  96.774194  77.419355  48.387097
# 64597       91236  train         01_tcp_ar  ...  96.774194  77.419355  48.387097
# 64598       91237  train         01_tcp_ar  ...  96.774194        NaN        NaN
#
# [38388 rows x 45 columns]

# %%
df_label_def = df_label_work.drop(['Unnamed: 0','Set','Categorie Montage','Dossier Patient','File N°','exam_duration','Pan_vs_XQRS','SWT_vs_XQRS','Session','max_duration','mean_nni%','csi%','hf%'],axis=1)

# %%
df_label_def
# Out:
#        Patient  ...                                   cle_exam
# 30        8615  ...  train_01_tcp_ar_8615_s001_2012_01_13_t000
# 31        8615  ...  train_01_tcp_ar_8615_s001_2012_01_13_t000
# 32        8615  ...  train_01_tcp_ar_8615_s001_2012_01_13_t000
# 33        8615  ...  train_01_tcp_ar_8615_s001_2012_01_13_t000
# 34        8615  ...  train_01_tcp_ar_8615_s001_2012_01_13_t000
# ...        ...  ...                                        ...
# 64594     8738  ...  train_01_tcp_ar_8738_s004_2013_06_04_t000
# 64595     8738  ...  train_01_tcp_ar_8738_s004_2013_06_04_t000
# 64596     8738  ...  train_01_tcp_ar_8738_s004_2013_06_04_t000
# 64597     8738  ...  train_01_tcp_ar_8738_s004_2013_06_04_t000
# 64598     8738  ...  train_01_tcp_ar_8738_s004_2013_06_04_t000
#
# [38388 rows x 32 columns]

# %%
df_RF = df_label_def.replace([np.inf, -np.inf], np.nan)

# %%
df_RF = df_RF.groupby(df_RF['cle_exam']).transform(lambda x: x.fillna(x.mean()))

# %%
df_RF
# Out:
#        Patient  interval_index  ...  ratio_sd2_sd1  label
# 30        8615             0.0  ...       3.966822    0.0
# 31        8615             1.0  ...       3.966822    0.0
# 32        8615             2.0  ...       3.966822    0.0
# 33        8615             3.0  ...       3.966822    0.0
# 34        8615             4.0  ...       3.966822    0.0
# ...        ...             ...  ...            ...    ...
# 64594     8738            17.0  ...       4.110496    0.0
# 64595     8738            18.0  ...       4.339563    0.0
# 64596     8738            19.0  ...       4.652542    0.0
# 64597     8738            20.0  ...       5.460270    0.0
# 64598     8738            21.0  ...      16.434398    0.0
#
# [38388 rows x 31 columns]

# %%
df_RF['label'] = df_RF['label'].apply(lambda x: "1" if (x!=0) else  "0" )

# %%
df_RF['label']
# Out:
# 30       0
# 31       0
# 32       0
# 33       0
# 34       0
#         ..
# 64594    0
# 64595    0
# 64596    0
# 64597    0
# 64598    0
# Name: label, Length: 38388, dtype: object

# %%
a = pd.Series(df_RF['label'])

# %%
a = pd.Series(df_RF['label'])

# %%
a.value_counts()
# Out:
# 0    36364
# 1     2024
# Name: label, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X = df_RF.iloc[:, :-1]
y = df_RF.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,stratify=y)

# %%
from sklearn.preprocessing import StandardScaler

numeric_transformer = StandardScaler()

X_train = numeric_transformer.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-0.26274593, -0.60584301, -0.60584301, ..., -0.94441468,
#         -0.91404633,  0.02389839],
#        [-0.26021657,  0.31438565,  0.31438565, ..., -0.195333  ,
#         -0.50858547, -0.00671435],
#        [ 0.88179064, -0.26404379, -0.26404379, ..., -0.92792804,
#         -0.83169407,  0.55003565],
#        ...,
#        [-2.55972333,  0.15663217,  0.15663217, ...,  1.86699064,
#          0.78728796, -0.77259314],
#        [-0.26274593, -0.13258255, -0.13258255, ..., -0.7253174 ,
#         -0.57432515,  0.39235482],
#        [ 0.32627938,  0.23550891,  0.23550891, ..., -0.88249032,
#         -0.63752605,  1.40490756]])

# %%
from sklearn.ensemble import RandomForestClassifier
rf_classifier = RandomForestClassifier(n_estimators=50)
rf_classifier.fit(X_train, y_train)
rf_classifier.score(X_train, y_train)
# Out:
# 0.999888355476164

# %%
from sklearn.model_selection import GridSearchCV
rf_classifier_grid = RandomForestClassifier()
params = {"n_estimators": range(20, 50)}

classifier = GridSearchCV(cv=10, estimator = rf_classifier_grid, param_grid = params).fit(X_train, y_train)

# %%
classifier.best_params_
# Out:
# {'n_estimators': 23}

# %%
X_test = numeric_transformer.fit_transform(X_test)

# %%
classifier.best_estimator_.score(X_test, y_test)
# Out:
# 0.9666579838499609

# %%
y_pred = classifier.predict(X_test)
print(y_pred)
# Out:
# ['0' '0' '0' ... '0' '0' '0']

# %%
from sklearn.metrics import f1_score
f1_score(y_test, y_pred,average='binary',pos_label='1')
# Out:
# 0.5879828326180258

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, labels=[0,1]))
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:565: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask &= (ar1 != a)
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98     10910
#            1       0.84      0.45      0.59       607
#
#    micro avg       0.97      0.97      0.97     11517
#    macro avg       0.91      0.72      0.79     11517
# weighted avg       0.96      0.97      0.96     11517

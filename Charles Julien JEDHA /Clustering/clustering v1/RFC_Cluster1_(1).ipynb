# %%
import pandas as pd
import numpy as np

# %%
df_cluster = pd.read_csv("df_cluster1.csv")

# %%
df_cluster.head()
# Out:
#    Unnamed: 0  Patient  ...  ratio_sd2_sd1_std  crisis_frequency
# 0           2       21  ...           1.084055          0.000000
# 1           4       54  ...           1.318584          0.007692
# 2           5       77  ...           1.401143          0.004525
# 3           6      107  ...           0.773588          0.006623
# 4           8      148  ...           2.625292          0.006623
#
# [5 rows x 58 columns]

# %%
s = pd.Series(df_cluster['Patient'])

# %%
s
# Out:
# 0         21
# 1         54
# 2         77
# 3        107
# 4        148
#        ...
# 297    12978
# 298    13010
# 299    13095
# 300    13112
# 301    13345
# Name: Patient, Length: 302, dtype: int64

# %%
l_1 = s.values.tolist()

# %%
l_1
# Out:
# [21,
#  54,
#  77,
#  107,
#  148,
#  184,
#  216,
#  244,
#  254,
#  272,
#  281,
#  302,
#  327,
#  404,
#  418,
#  473,
#  492,
#  499,
#  502,
#  526,
#  529,
#  569,
#  574,
#  576,
#  577,
#  598,
#  604,
#  630,
#  704,
#  705,
#  820,
#  850,
#  883,
#  924,
#  940,
#  1006,
#  1046,
#  1050,
#  1116,
#  1188,
#  1204,
#  1217,
#  1267,
#  1278,
#  1317,
#  1369,
#  1402,
#  1413,
#  1482,
#  1503,
#  1543,
#  1545,
#  1548,
#  1620,
#  1653,
#  1690,
#  1698,
#  1753,
#  1770,
#  1781,
#  1851,
#  1864,
#  1878,
#  1945,
#  1981,
#  2000,
#  2051,
#  2056,
#  2126,
#  2214,
#  2225,
#  2260,
#  2271,
#  2322,
#  2384,
#  2394,
#  2427,
#  2435,
#  2484,
#  2500,
#  2521,
#  2543,
#  2568,
#  2707,
#  2724,
#  2752,
#  2760,
#  2827,
#  2847,
#  2921,
#  2991,
#  3005,
#  3038,
#  3144,
#  3284,
#  3306,
#  3318,
#  3346,
#  3401,
#  3419,
#  3437,
#  3489,
#  3635,
#  3668,
#  3674,
#  3760,
#  3884,
#  3885,
#  3960,
#  3988,
#  4030,
#  4041,
#  4045,
#  4047,
#  4126,
#  4151,
#  4185,
#  4374,
#  4456,
#  4473,
#  4594,
#  4657,
#  4671,
#  4692,
#  4719,
#  4759,
#  4774,
#  4842,
#  4865,
#  4892,
#  5034,
#  5095,
#  5096,
#  5101,
#  5130,
#  5180,
#  5183,
#  5213,
#  5265,
#  5301,
#  5346,
#  5411,
#  5452,
#  5469,
#  5575,
#  5625,
#  5649,
#  5672,
#  5936,
#  5943,
#  6059,
#  6083,
#  6087,
#  6139,
#  6175,
#  6230,
#  6413,
#  6440,
#  6444,
#  6501,
#  6515,
#  6529,
#  6544,
#  6607,
#  6648,
#  6699,
#  6811,
#  6864,
#  7067,
#  7108,
#  7128,
#  7130,
#  7170,
#  7216,
#  7234,
#  7252,
#  7255,
#  7307,
#  7313,
#  7374,
#  7431,
#  7504,
#  7584,
#  7623,
#  7656,
#  7665,
#  7772,
#  7773,
#  7793,
#  7795,
#  7797,
#  7891,
#  7936,
#  8018,
#  8056,
#  8092,
#  8143,
#  8292,
#  8303,
#  8440,
#  8444,
#  8460,
#  8476,
#  8480,
#  8487,
#  8492,
#  8527,
#  8544,
#  8550,
#  8552,
#  8561,
#  8573,
#  8579,
#  8606,
#  8608,
#  8628,
#  8660,
#  8760,
#  8884,
#  8889,
#  8941,
#  9030,
#  9104,
#  9110,
#  9232,
#  9297,
#  9370,
#  9444,
#  9455,
#  9510,
#  9525,
#  9532,
#  9540,
#  9572,
#  9578,
#  9623,
#  9734,
#  9762,
#  9842,
#  9881,
#  9934,
#  9958,
#  9994,
#  10023,
#  10035,
#  10061,
#  10104,
#  10106,
#  10164,
#  10209,
#  10234,
#  10247,
#  10268,
#  10275,
#  10291,
#  10321,
#  10427,
#  10455,
#  10461,
#  10489,
#  10547,
#  10587,
#  10591,
#  10736,
#  10760,
#  10798,
#  10850,
#  10861,
#  10912,
#  10969,
#  11077,
#  11149,
#  11171,
#  11248,
#  11272,
#  11321,
#  11549,
#  11562,
#  11596,
#  11622,
#  11869,
#  11902,
#  11915,
#  11981,
#  11999,
#  12046,
#  12070,
#  12185,
#  12409,
#  12418,
#  12484,
#  12642,
#  12751,
#  12759,
#  12786,
#  12870,
#  12941,
#  12978,
#  13010,
#  13095,
#  13112,
#  13345]

# %%
df_label = pd.read_csv('xqrs_v2_cleaned.csv')

# %%
df_label.head()
# Out:
#    Unnamed: 0    Set Categorie Montage  ...  mean_nni%       csi%        hf%
# 0         193  train         01_tcp_ar  ...      100.0  76.666667  46.666667
# 1         194  train         01_tcp_ar  ...      100.0  76.666667  46.666667
# 2         195  train         01_tcp_ar  ...      100.0  76.666667  46.666667
# 3         196  train         01_tcp_ar  ...      100.0  76.666667  46.666667
# 4         197  train         01_tcp_ar  ...      100.0  76.666667  46.666667
#
# [5 rows x 45 columns]

# %%
df_label_work = df_label[df_label['Patient'].isin(l_1)]

# %%
df_label_work
# Out:
#        Unnamed: 0    Set Categorie Montage  ...  mean_nni%       csi%        hf%
# 300          1289  train         01_tcp_ar  ...      100.0  95.035461  88.652482
# 301          1290  train         01_tcp_ar  ...      100.0  95.035461  88.652482
# 302          1291  train         01_tcp_ar  ...      100.0  95.035461  88.652482
# 303          1292  train         01_tcp_ar  ...      100.0  95.035461  88.652482
# 304          1293  train         01_tcp_ar  ...      100.0  95.035461  88.652482
# ...           ...    ...               ...  ...        ...        ...        ...
# 24711       32688  train         01_tcp_ar  ...      100.0  74.074074  40.740741
# 24712       32689  train         01_tcp_ar  ...      100.0  74.074074  40.740741
# 24713       32690  train         01_tcp_ar  ...      100.0  74.074074  40.740741
# 24714       32691  train         01_tcp_ar  ...      100.0  74.074074  40.740741
# 24715       32692  train         01_tcp_ar  ...      100.0  74.074074  40.740741
#
# [16086 rows x 45 columns]

# %%
df_label_def = df_label_work.drop(['Unnamed: 0','Set','Categorie Montage','Dossier Patient','File N°','exam_duration','Pan_vs_XQRS','SWT_vs_XQRS','Session','max_duration','mean_nni%','csi%','hf%'],axis=1)

# %%
df_label_def
# Out:
#        Patient  ...                                   cle_exam
# 300       8628  ...  train_01_tcp_ar_8628_s001_2012_01_10_t000
# 301       8628  ...  train_01_tcp_ar_8628_s001_2012_01_10_t000
# 302       8628  ...  train_01_tcp_ar_8628_s001_2012_01_10_t000
# 303       8628  ...  train_01_tcp_ar_8628_s001_2012_01_10_t000
# 304       8628  ...  train_01_tcp_ar_8628_s001_2012_01_10_t000
# ...        ...  ...                                        ...
# 24711     8143  ...  train_01_tcp_ar_8143_s009_2011_11_16_t003
# 24712     8143  ...  train_01_tcp_ar_8143_s009_2011_11_16_t003
# 24713     8143  ...  train_01_tcp_ar_8143_s009_2011_11_16_t003
# 24714     8143  ...  train_01_tcp_ar_8143_s009_2011_11_16_t003
# 24715     8143  ...  train_01_tcp_ar_8143_s009_2011_11_16_t003
#
# [16086 rows x 32 columns]

# %%
df_RF = df_label_def.replace([np.inf, -np.inf], np.nan)

# %%
df_RF = df_RF.groupby(df_RF['cle_exam']).transform(lambda x: x.fillna(x.mean()))

# %%
df_RF
# Out:
#        Patient  interval_index  ...  ratio_sd2_sd1  label
# 300       8628             0.0  ...       4.087992    0.0
# 301       8628             1.0  ...       4.087992    0.0
# 302       8628             2.0  ...       4.087992    0.0
# 303       8628             3.0  ...       4.087992    0.0
# 304       8628             4.0  ...       4.087992    0.0
# ...        ...             ...  ...            ...    ...
# 24711     8143            22.0  ...       5.848010    0.0
# 24712     8143            23.0  ...       5.378746    0.0
# 24713     8143            24.0  ...       5.354722    0.0
# 24714     8143            25.0  ...       7.966664    0.0
# 24715     8143            26.0  ...      10.627203    0.0
#
# [16086 rows x 31 columns]

# %%
df_RF['label'] = df_RF['label'].apply(lambda x: "1" if (x!=0) else  "0" )

# %%
df_RF['label']
# Out:
# 300      0
# 301      0
# 302      0
# 303      0
# 304      0
#         ..
# 24711    0
# 24712    0
# 24713    0
# 24714    0
# 24715    0
# Name: label, Length: 16086, dtype: object

# %%
a = pd.Series(df_RF['label'])

# %%
a.value_counts()
# Out:
# 0    15663
# 1      423
# Name: label, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X = df_RF.iloc[:, :-1]
y = df_RF.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,stratify=y)

# %%
from sklearn.preprocessing import StandardScaler

numeric_transformer = StandardScaler()

X_train = numeric_transformer.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.50183923,  0.54113078,  0.54113078, ..., -0.85275089,
#         -1.01188119, -1.02358749],
#        [ 0.5220757 , -0.30027119, -0.30027119, ...,  2.00799284,
#          1.16749685, -0.64533533],
#        [-0.30256051,  0.26066345,  0.26066345, ..., -0.72365395,
#         -1.00838756, -1.27476422],
#        ...,
#        [-0.27333005, -0.86120584, -0.86120584, ..., -0.50571928,
#         -0.38582365,  0.20946344],
#        [-0.71403542, -0.76103893, -0.76103893, ...,  1.01621145,
#          1.45000019,  0.10817585],
#        [ 1.42259867,  2.9451364 ,  2.9451364 , ..., -0.67322245,
#         -0.37656814,  0.95927627]])

# %%
from sklearn.ensemble import RandomForestClassifier
rf_classifier = RandomForestClassifier(n_estimators=50)
rf_classifier.fit(X_train, y_train)
rf_classifier.score(X_train, y_train)
# Out:
# 0.9996447602131439

# %%
from sklearn.model_selection import GridSearchCV
rf_classifier_grid = RandomForestClassifier()
params = {"n_estimators": range(20, 50)}

classifier = GridSearchCV(cv=10, estimator = rf_classifier_grid, param_grid = params).fit(X_train, y_train)

# %%
classifier.best_params_
# Out:
# {'n_estimators': 39}

# %%
X_test = numeric_transformer.fit_transform(X_test)

# %%
classifier.best_estimator_.score(X_test, y_test)
# Out:
# 0.9825942809780357

# %%
y_pred = classifier.predict(X_test)
print(y_pred)
# Out:
# ['0' '0' '0' ... '0' '0' '0']

# %%
print(y_test)
# Out:
# 5514     0
# 14439    0
# 14137    0
# 7078     0
# 18261    0
#         ..
# 14997    0
# 17750    0
# 17195    1
# 8242     0
# 7369     0
# Name: label, Length: 4826, dtype: object

# %%
from sklearn.metrics import f1_score
f1_score(y_test, y_pred ,average='binary',pos_label='1')
# Out:
# 0.5280898876404494

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      4699
#            1       0.92      0.37      0.53       127
#
#    micro avg       0.98      0.98      0.98      4826
#    macro avg       0.95      0.68      0.76      4826
# weighted avg       0.98      0.98      0.98      4826
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:565: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask &= (ar1 != a)
